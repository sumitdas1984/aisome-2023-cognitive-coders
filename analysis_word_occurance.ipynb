# %%
import pandas as pd
from collections import Counter
import ast
pd.options.display.max_rows = 1000

df=pd.read_csv("train_with_entities.csv", index_col=0)
df.shape
# Out:
# (9921, 3)

# %% [markdown]
# Most occuring entity group for each labels in complete data

# %%
def get_most_occuring_entity_group(entities_list):
    entity_counts = {}
    
    converted_list = ast.literal_eval(entities_list)
    for entity in converted_list:
        entity_group = entity['entity_group']
        entity_counts[entity_group] = entity_counts.get(entity_group, 0) + 1

    if entity_counts:
        most_occuring_entity_group = max(entity_counts, key=entity_counts.get)
    else:
        most_occuring_entity_group = 'UNKNOWN'
    
    return most_occuring_entity_group

most_occuring_entities = new_df.groupby('labels')['with_entities'].apply(lambda x: get_most_occuring_entity_group(x.iloc[0]))

result_df = most_occuring_entities.reset_index()
result_df.columns = ['Labels', 'Most_Occurring_Entity_Group']

print(result_df)
# Out:
#                                   Labels Most_Occurring_Entity_Group
# 0                             conspiracy                         ORG
# 1                     conspiracy country                         PER
# 2         conspiracy country ingredients                         ORG
# 3              conspiracy country pharma                        MISC
# 4         conspiracy country side-effect                        MISC
# 5                 conspiracy ineffective                         PER
# 6     conspiracy ineffective ingredients                         ORG
# 7     conspiracy ineffective side-effect                         PER
# 8                 conspiracy ingredients                        MISC
# 9       conspiracy ingredients mandatory                         PER
# 10         conspiracy ingredients pharma                         PER
# 11      conspiracy ingredients religious                        MISC
# 12    conspiracy ingredients side-effect                         LOC
# ...

# %%
# def get_most_occuring_entity_group(entities_list):
#     entity_counts = {}
    
#     converted_list = ast.literal_eval(entities_list)
#     for entity in converted_list:
#         entity_group = entity['entity_group']
#         print(entity_group)
#         entity_counts[entity_group] = entity_counts.get(entity_group, 0) + 1

#     if entity_counts:
#         most_occuring_entity_group = max(entity_counts, key=entity_counts.get)
#     else:
#         most_occuring_entity_group = 'UNKNOWN'
    
#     return most_occuring_entity_group

def get_most_occuring_entity_groups(entities_list, top_n=3):
    entities_list = ast.literal_eval(entities_list)
    entity_counts = Counter(entity['entity_group'] for entity in entities_list)
    most_occuring_entity_groups = entity_counts.most_common(top_n)
    return [entity_group for entity_group, _ in most_occuring_entity_groups]

new_df = df.dropna()
most_occuring_entities = filtered_df.groupby('labels')['with_entities'].apply(lambda x: get_most_occuring_entity_groups(x.iloc[0]))

result_df = most_occuring_entities.reset_index()
result_df.columns = ['Labels', 'Top_Entity_Groups']

print(result_df)



# most_occuring_entities = new_df.groupby('labels')['with_entities'].apply(lambda x: get_most_occuring_entity_groups(x.iloc[0]))

# result_df = most_occuring_entities.reset_index()
# result_df.columns = ['Labels', 'Most_Occurring_Entity_Group']

# print(result_df)
# Out:
#          Labels Top_Entity_Groups
# 0    conspiracy        [ORG, PER]
# 1       country  [PER, MISC, ORG]
# 2   ineffective  [PER, MISC, ORG]
# 3   ingredients        [PER, ORG]
# 4     mandatory             [PER]
# 5          none                []
# 6        pharma        [ORG, PER]
# 7     political       [MISC, PER]
# 8     religious            [MISC]
# 9        rushed        [ORG, LOC]
# 10  side-effect  [ORG, LOC, MISC]
# 11  unnecessary             [PER]

# %% [markdown]
# Most occuring entity group for subset of labels in complete data

# %%
selected_labels =  ['ingredients','side-effect','mandatory','political','none','conspiracy','country','pharma','ineffective','rushed','unnecessary','religious']
filtered_df = df[df['labels'].isin(selected_labels)]
filtered_df = filtered_df.dropna(subset=['with_entities'])
filtered_df.head()
# Out:
#                                                tweet       labels
# 0  @cath__kath AstraZeneca is made with the kidne...  ingredients  \
# 1  It begins. Please find safe alternatives to th...  side-effect
# 2  @PaolaQP1231 Well, I mean congratulations Covi...  side-effect
# 7  @AgreeT0D1sagree @Matteo30115900 @Femi_Sorry I...    mandatory
# 8  Taking One for the Team #TeamCanada New Astra~...  side-effect
#
#                                        with_entities
# 0  [{'entity_group': 'PER', 'score': 0.8894829750...
# 1  [{'entity_group': 'LOC', 'score': 0.9151143431...
# 2  [{'entity_group': 'ORG', 'score': 0.6813083887...
# 7  [{'entity_group': 'PER', 'score': 0.9550597667...
# 8  [{'entity_group': 'LOC', 'score': 0.9232296943...

# %%
filtered_df.shape
# Out:
# (7683, 3)

# %%
def get_most_occuring_entity_group(entities_list):
    entity_counts = {}
    converted_list = ast.literal_eval(entities_list)
    for entity in converted_list:
        entity_group = entity['entity_group']
        entity_counts[entity_group] = entity_counts.get(entity_group, 0) + 1

    if entity_counts:
        most_occuring_entity_group = max(entity_counts, key=entity_counts.get)
    else:
        most_occuring_entity_group = 'UNKNOWN'
    
    return most_occuring_entity_group

most_occuring_entities = filtered_df.groupby('labels')['with_entities'].apply(lambda x: get_most_occuring_entity_group(x.iloc[0]))

result_df = most_occuring_entities.reset_index()
result_df.columns = ['Labels', 'Most_Occurring_Entity_Group']

print(result_df)
# Out:
#          Labels Most_Occurring_Entity_Group
# 0    conspiracy                         ORG
# 1       country                         PER
# 2   ineffective                         PER
# 3   ingredients                         PER
# 4     mandatory                         PER
# 5          none                     UNKNOWN
# 6        pharma                         ORG
# 7     political                        MISC
# 8     religious                        MISC
# 9        rushed                         ORG
# 10  side-effect                         ORG
# 11  unnecessary                         PER

# %% [markdown]
# Get occurance

# %%
#['ingredients','side-effect','mandatory','political','none','conspiracy','country','pharma','ineffective','rushed','unnecessary','religious']
ingredients_df = filtered_df[filtered_df['labels'] == 'ingredients']
ingredients_df.name = 'ingredients'
side_effect_df = filtered_df[filtered_df['labels'] == 'side-effect']
side_effect_df.name = 'side_effect'
mandatory_df = filtered_df[filtered_df['labels'] == 'mandatory']
mandatory_df.name = 'mandatory'
political_df = filtered_df[filtered_df['labels'] == 'political']
political_df.name = 'political'
none_df = filtered_df[filtered_df['labels'] == 'none']
none_df.name = 'none'
conspiracy_df = filtered_df[filtered_df['labels'] == 'conspiracy']
conspiracy_df.name = 'conspiracy'
country_df = filtered_df[filtered_df['labels'] == 'country']
country_df.name = 'country'
pharma_df = filtered_df[filtered_df['labels'] == 'pharma']
pharma_df.name = 'pharma'
rushed_df = filtered_df[filtered_df['labels'] == 'rushed']
rushed_df.name = 'rushed'
unnecessary_df = filtered_df[filtered_df['labels'] == 'unnecessary']
unnecessary_df.name = 'unnecessary'
ineffective_df = filtered_df[filtered_df['labels'] == 'ineffective']
ineffective_df.name = 'ineffective'
religious_df = filtered_df[filtered_df['labels'] == 'religious']
religious_df.name = 'religious'

# %%
ingredients_df.shape, side_effect_df.shape, mandatory_df.shape, political_df.shape, none_df.shape, conspiracy_df.shape, country_df.shape,pharma_df.shape, rushed_df.shape, unnecessary_df.shape,ineffective_df.shape, religious_df.shape
# Out:
# ((187, 3),
#  (2799, 3),
#  (499, 3),
#  (328, 3),
#  (618, 3),
#  (144, 3),
#  (110, 3),
#  (726, 3),
#  (752, 3),
#  (349, 3),
#  (1142, 3),
#  (29, 3))

# %%
def get_word_occurance_ingredients(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_ingredients=[]
def has_entity_group_ingredients(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'PER':
            all_values_ingredients.append(entry['word'])
            return True
    return False

def get_word_occurance_side_effect(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_side_effect=[]
def has_entity_group_side_effect(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'ORG':
            all_values_side_effect.append(entry['word'])
            return True
    return False


def get_word_occurance_mandatory(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_mandatory=[]
def has_entity_group_mandatory(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'PER':
            all_values_mandatory.append(entry['word'])
            return True
    return False


def get_word_occurance_political(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_political=[]
def has_entity_group_political(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'MISC':
            all_values_political.append(entry['word'])
            return True
    return False






def get_word_occurance_none(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_none=[]
def has_entity_group_none(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'UNKNOWN':
            all_values_none.append(entry['word'])
            return True
    return False


def get_word_occurance_conspiracy(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_conspiracy=[]
def has_entity_group_conspiracy(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'ORG':
            all_values_conspiracy.append(entry['word'])
            return True
    return False



def get_word_occurance_country(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_country=[]
def has_entity_group_country(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'PER':
            all_values_country.append(entry['word'])
            return True
    return False



def get_word_occurance_pharma(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_pharma=[]
def has_entity_group_pharma(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'ORG':
            all_values_pharma.append(entry['word'])
            return True
    return False


def get_word_occurance_rushed(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_rushed=[]
def has_entity_group_rushed(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'ORG':
            all_values_rushed.append(entry['word'])
            return True
    return False



def get_word_occurance_unnecessary(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_unnecessary=[]
def has_entity_group_unnecessary(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'PER':
            all_values_unnecessary.append(entry['word'])
            return True
    return False


def get_word_occurance_ineffective(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_ineffective=[]
def has_entity_group_ineffective(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'PER':
            all_values_ineffective.append(entry['word'])
            return True
    return False


def get_word_occurance_religious(all_values):
    # Count the occurrences of each element in the list
    counted_elements = Counter(all_values)

    # Sort the elements based on their occurrences in descending order
    sorted_elements = counted_elements.most_common()

    # Display the result
    for value, count in sorted_elements[:10]:
        print(f"{value} - {count} occurrences")
    
all_values_religious=[]
def has_entity_group_religious(entity_list):
    converted_list = ast.literal_eval(entity_list)
    for entry in converted_list:
        if entry['entity_group'] == 'MISC':
            all_values_religious.append(entry['word'])
            return True
    return False

# %%
print("For dataframe: ",ingredients_df.name)
print("----------------------------------")
local_df = ingredients_df[ingredients_df['with_entities'].apply(has_entity_group_ingredients)] 
get_word_occurance_ingredients(all_values_ingredients)
print("======================================")
print("For dataframe: ",side_effect_df.name)
print("----------------------------------")
local_df = side_effect_df[side_effect_df['with_entities'].apply(has_entity_group_side_effect)] 
get_word_occurance_side_effect(all_values_side_effect)
print("======================================")
print("For dataframe: ",mandatory_df.name)
print("----------------------------------")
local_df = mandatory_df[mandatory_df['with_entities'].apply(has_entity_group_mandatory)] 
get_word_occurance_mandatory(all_values_mandatory)
print("======================================")
print("For dataframe: ",political_df.name)
print("----------------------------------")
local_df = political_df[political_df['with_entities'].apply(has_entity_group_political)] 
get_word_occurance_political(all_values_political)
print("======================================")
print("For dataframe: ",none_df.name)
print("----------------------------------")
local_df = none_df[none_df['with_entities'].apply(has_entity_group_none)] 
get_word_occurance_none(all_values_none)
print("======================================")
print("For dataframe: ",conspiracy_df.name)
print("----------------------------------")
local_df = conspiracy_df[conspiracy_df['with_entities'].apply(has_entity_group_conspiracy)] 
get_word_occurance_conspiracy(all_values_conspiracy)
print("======================================")
print("For dataframe: ",country_df.name)
print("----------------------------------")
local_df = country_df[country_df['with_entities'].apply(has_entity_group_country)] 
get_word_occurance_country(all_values_country)
print("======================================")
print("For dataframe: ",pharma_df.name)
print("----------------------------------")
local_df = pharma_df[pharma_df['with_entities'].apply(has_entity_group_pharma)] 
get_word_occurance_pharma(all_values_pharma)
print("======================================")
print("For dataframe: ",rushed_df.name)
print("----------------------------------")
local_df = rushed_df[rushed_df['with_entities'].apply(has_entity_group_rushed)] 
get_word_occurance_rushed(all_values_rushed)
print("======================================")
print("For dataframe: ",unnecessary_df.name)
print("----------------------------------")
local_df = unnecessary_df[unnecessary_df['with_entities'].apply(has_entity_group_unnecessary)] 
get_word_occurance_unnecessary(all_values_unnecessary)
print("======================================")
print("For dataframe: ",ineffective_df.name)
print("----------------------------------")
local_df = ineffective_df[ineffective_df['with_entities'].apply(has_entity_group_ineffective)] 
get_word_occurance_ineffective(all_values_ineffective)
print("======================================")
print("For dataframe: ",religious_df.name)
print("----------------------------------")
local_df = religious_df[religious_df['with_entities'].apply(has_entity_group_religious)] 
get_word_occurance_religious(all_values_religious)
print("======================================")
# Out:
# For dataframe:  ingredients
# ----------------------------------
# Fauci - 3 occurrences
# cath__kath - 2 occurrences
# TiceRichard - 2 occurrences
# Jesus@@ - 2 occurrences
# ju@@ - 2 occurrences
# v@@ - 2 occurrences
# LethFourr - 2 occurrences
# DanScavino - 2 occurrences
# Q - 2 occurrences
# krismeloche - 2 occurrences
# ...
# For dataframe:  side_effect
# ----------------------------------
# Pfizer - 373 occurrences
# AstraZeneca - 159 occurrences
# Pfizer@@ - 82 occurrences
# Johnson & Johnson - 58 occurrences
# fizer - 46 occurrences
# pfizer - 39 occurrences
# A@@ - 38 occurrences
# FDA - 38 occurrences
# CDC - 27 occurrences
# fi@@ - 19 occurrences
# ...
# For dataframe:  mandatory
# ----------------------------------
# BorisJohnson - 12 occurrences
# Cromwell@@ - 3 occurrences
# ScottMorrison@@ - 3 occurrences
# AlexBerenson - 3 occurrences
# Matt@@ - 2 occurrences
# AndyReid@@ - 2 occurrences
# MCRobredz - 2 occurrences
# ir@@ - 2 occurrences
# wendyemily@@ - 2 occurrences
# ...
